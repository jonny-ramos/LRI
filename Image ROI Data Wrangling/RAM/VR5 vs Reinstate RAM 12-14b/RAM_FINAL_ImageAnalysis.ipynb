# %%
import numpy as np
import pandas as pd
import glob
import sys

# loading some functions we wrote before
sys.path.append("/Users/jonathanramos/Desktop/LRI/Image ROI Data Wrangling/")
from clean import *
from norm import *
from count import *

# %%
df = pd.read_csv('RAM-12,13,14_FINAL.csv')
df_redo = pd.read_csv('RAM-REDO_FINAL.csv')

set(df.columns) - set(df_redo.columns)
# Out:
# {'CoM_x',
#  'CoM_y',
#  'dox',
#  'grouping',
#  'iid_rid',
#  'mean_intensity',
#  'rat_n',
#  'react',
#  'treatment'}

# %% [markdown]
# # Adding labels to redo set

# %%
# load in key, standardize cols and labels
df_key = pd.read_csv('RAM Ensembles Complete Cohort Key.csv')
df_key['Group'] = df_key.Group.replace('RAM-14_a', 'RAM-14a').replace('RAM-14_b', 'RAM-14b')
df_key['rat_n'] = df_key.apply(lambda x: '_'.join([x['Group'], str(x['Rat ID'])]), axis=1)
df_key['treatment'] = df_key['ABC/Veh'].str.upper()
df_key['dox'] = df_key['Dox Tx'].str.replace(' ', '_').str.upper()
df_key['react'] = df_key['React'].str.upper()

# select out the cols we are interested in
df_key = df_key[['rat_n', 'react', 'treatment', 'dox']]

### add missing rat information; this was confirmed by AG
df_key.loc[-1] = ['RAM-13_7', 'NR', 'ABC', 'OFF_DOX']
df_key.index = df_key.index + 1
df_key = df_key.sort_index()


def get_cols(df, df_key):
    # parse filename to build rat_n, image_name
    df['rat_n'] = df.filename.str.split('_').apply(lambda x: '_'.join(x[:2]))

    # merge with key on rat_n
    df = df.merge(df_key, how='left', on='rat_n')

    return df

df_redo = get_cols(df_redo, df_key)
df_redo = df_redo.rename(columns={'xm': 'CoM_x', 'ym': 'CoM_y', 'mean': 'mean_intensity', 'roi_id':'iid_rid', 'roi_id.1': 'roi_id'})

# %% [markdown]
# # Concat full set and redo set

# %%
df = df[['iid_rid', 'dummy_cFos', 'dummy_EGFP', 'dummy_mKate',
    'image_name', 'roi_id', 'stain', 'CoM_x', 'CoM_y', 'background',
    'mean_intensity', 'filename', 'rat_n', 'react', 'treatment', 'dox',
    'true_grouping']]

df_redo = df_redo[['iid_rid', 'dummy_cFos', 'dummy_EGFP', 'dummy_mKate',
    'image_name', 'roi_id', 'stain', 'CoM_x', 'CoM_y', 'background',
    'mean_intensity', 'filename', 'rat_n', 'react', 'treatment', 'dox',
    'true_grouping']]


df_full = pd.concat([df, df_redo])
print(f'shape: {df_full.shape}')

duplicates = df_full.duplicated(subset=['CoM_x', 'CoM_y', 'roi_id', 'image_name', 'mean_intensity', 'background']).sum()
print(f'\nduplicates: {duplicates}')

print('\nNaNs per col:')
print(df_full.isna().sum())
df_full.head()
# Out:
# shape: (43483, 17)
#
# duplicates: 0
#
# NaNs per col:
# iid_rid            0
# dummy_cFos         0
# dummy_EGFP         0
# dummy_mKate        0
# image_name         0
# roi_id             0
# stain              0
# CoM_x             31
# CoM_y             31
# background         0
# mean_intensity    31
# filename           0
# rat_n              0
# react              0
# treatment          0
# dox                0
# true_grouping      0
# dtype: int64
#                                  iid_rid  dummy_cFos  dummy_EGFP  dummy_mKate  \
# 0  RAM-12_11_PFC_3.5_A_0-002-00000_mKate       False        True         True
# 1  RAM-12_11_PFC_3.5_A_0-002-00001_mKate       False       False         True
# 2  RAM-12_11_PFC_3.5_A_0-002-00002_mKate       False        True         True
# 3  RAM-12_11_PFC_3.5_A_0-002-00003_mKate       False        True         True
# 4  RAM-12_11_PFC_3.5_A_0-002-00004_mKate       False        True         True
#
#             image_name             roi_id  stain   CoM_x   CoM_y  background  \
# 0  RAM-12_11_PFC_3.5_A  0-002-00000_mKate  mKate  490.69  263.66     54.2523
# 1  RAM-12_11_PFC_3.5_A  0-002-00001_mKate  mKate  359.15  417.22     54.2523
# 2  RAM-12_11_PFC_3.5_A  0-002-00002_mKate  mKate  149.95  354.17     54.2523
# 3  RAM-12_11_PFC_3.5_A  0-002-00003_mKate  mKate  193.05  160.84     54.2523
# 4  RAM-12_11_PFC_3.5_A  0-002-00004_mKate  mKate  221.09  254.73     54.2523
#
#    mean_intensity                   filename      rat_n react treatment  \
# 0        130.8234  RAM-12_11_PFC_3.5_A_4.tif  RAM-12_11   VR5       ABC
# 1        252.4054  RAM-12_11_PFC_3.5_A_4.tif  RAM-12_11   VR5       ABC
# 2        910.3442  RAM-12_11_PFC_3.5_A_4.tif  RAM-12_11   VR5       ABC
# 3        280.5944  RAM-12_11_PFC_3.5_A_4.tif  RAM-12_11   VR5       ABC
# 4        237.5106  RAM-12_11_PFC_3.5_A_4.tif  RAM-12_11   VR5       ABC
#
#        dox                              true_grouping
# 0  OFF_DOX  ('0-01c-00028_EGFP', '0-002-00000_mKate')
# 1  OFF_DOX                     ('0-002-00001_mKate',)
# 2  OFF_DOX  ('0-01c-00047_EGFP', '0-002-00002_mKate')
# 3  OFF_DOX  ('0-01c-00128_EGFP', '0-002-00003_mKate')
# 4  OFF_DOX  ('0-FFF-00238_EGFP', '0-002-00004_mKate')

# %%
# dropping those 31 rows containing nans
df_full = df_full.dropna()
print(f'shape: {df_full.shape}')
# Out:
# shape: (43452, 17)

# %% [markdown]
# ## compute normalized mean-background

# %%
df_full['mean-background'] = df_full.mean_intensity - df_full.background
norm_condition = df_full.query('dox == "ON_DOX" and react == "FR1"')['mean-background'].mean()
df_full['norm_mean-background'] = df_full['mean-background'] / norm_condition

df_full
# Out:
#                                     iid_rid  dummy_cFos  dummy_EGFP  \
# 0     RAM-12_11_PFC_3.5_A_0-002-00000_mKate       False        True
# 1     RAM-12_11_PFC_3.5_A_0-002-00001_mKate       False       False
# 2     RAM-12_11_PFC_3.5_A_0-002-00002_mKate       False        True
# 3     RAM-12_11_PFC_3.5_A_0-002-00003_mKate       False        True
# 4     RAM-12_11_PFC_3.5_A_0-002-00004_mKate       False        True
# ...                                     ...         ...         ...
# 2225           RAM-12_14_PFC_4.0_B_mKate_45       False       False
# 2226           RAM-12_14_PFC_4.0_B_mKate_46       False        True
# 2227           RAM-12_14_PFC_4.0_B_mKate_47       False        True
# 2228           RAM-12_14_PFC_4.0_B_mKate_48       False       False
# 2229           RAM-12_14_PFC_4.0_B_mKate_49       False       False
#
#       dummy_mKate           image_name                        roi_id  stain  \
# 0            True  RAM-12_11_PFC_3.5_A             0-002-00000_mKate  mKate
# 1            True  RAM-12_11_PFC_3.5_A             0-002-00001_mKate  mKate
# 2            True  RAM-12_11_PFC_3.5_A             0-002-00002_mKate  mKate
# 3            True  RAM-12_11_PFC_3.5_A             0-002-00003_mKate  mKate
# 4            True  RAM-12_11_PFC_3.5_A             0-002-00004_mKate  mKate
# ...           ...                  ...                           ...    ...
# 2225         True  RAM-12_14_PFC_4.0_B  RAM-12_14_PFC_4.0_B_mKate_45  mKate
# 2226         True  RAM-12_14_PFC_4.0_B  RAM-12_14_PFC_4.0_B_mKate_46  mKate
# 2227         True  RAM-12_14_PFC_4.0_B  RAM-12_14_PFC_4.0_B_mKate_47  mKate
# 2228         True  RAM-12_14_PFC_4.0_B  RAM-12_14_PFC_4.0_B_mKate_48  mKate
# 2229         True  RAM-12_14_PFC_4.0_B  RAM-12_14_PFC_4.0_B_mKate_49  mKate
#
#         CoM_x    CoM_y  background  mean_intensity                   filename  \
# 0     490.690  263.660     54.2523        130.8234  RAM-12_11_PFC_3.5_A_4.tif
# 1     359.150  417.220     54.2523        252.4054  RAM-12_11_PFC_3.5_A_4.tif
# 2     149.950  354.170     54.2523        910.3442  RAM-12_11_PFC_3.5_A_4.tif
# 3     193.050  160.840     54.2523        280.5944  RAM-12_11_PFC_3.5_A_4.tif
# 4     221.090  254.730     54.2523        237.5106  RAM-12_11_PFC_3.5_A_4.tif
# ...       ...      ...         ...             ...                        ...
# 2225  126.038  396.117     19.5310        221.3070      RAM-12_14_PFC_4.0_B_4
# 2226   20.795  385.174     19.5310        513.8450      RAM-12_14_PFC_4.0_B_4
# 2227   48.338  409.231     19.5310         82.0070      RAM-12_14_PFC_4.0_B_4
# 2228   79.833  159.605     19.5310         71.3380      RAM-12_14_PFC_4.0_B_4
# 2229   13.826  216.995     19.5310         81.6740      RAM-12_14_PFC_4.0_B_4
#
#           rat_n react treatment      dox  \
# 0     RAM-12_11   VR5       ABC  OFF_DOX
# 1     RAM-12_11   VR5       ABC  OFF_DOX
# 2     RAM-12_11   VR5       ABC  OFF_DOX
# 3     RAM-12_11   VR5       ABC  OFF_DOX
# 4     RAM-12_11   VR5       ABC  OFF_DOX
# ...         ...   ...       ...      ...
# 2225  RAM-12_14    NR       VEH  OFF_DOX
# 2226  RAM-12_14    NR       VEH  OFF_DOX
# 2227  RAM-12_14    NR       VEH  OFF_DOX
# 2228  RAM-12_14    NR       VEH  OFF_DOX
# 2229  RAM-12_14    NR       VEH  OFF_DOX
#
#                                           true_grouping  mean-background  \
# 0             ('0-01c-00028_EGFP', '0-002-00000_mKate')          76.5711
# 1                                ('0-002-00001_mKate',)         198.1531
# 2             ('0-01c-00047_EGFP', '0-002-00002_mKate')         856.0919
# 3             ('0-01c-00128_EGFP', '0-002-00003_mKate')         226.3421
# 4             ('0-FFF-00238_EGFP', '0-002-00004_mKate')         183.2583
# ...                                                 ...              ...
# 2225                  ('RAM-12_14_PFC_4.0_B_mKate_45',)         201.7760
# 2226  ('RAM-12_14_PFC_4.0_B_EGFP_300', 'RAM-12_14_PF...         494.3140
# 2227  ('RAM-12_14_PFC_4.0_B_EGFP_299', 'RAM-12_14_PF...          62.4760
# 2228                  ('RAM-12_14_PFC_4.0_B_mKate_48',)          51.8070
# 2229                  ('RAM-12_14_PFC_4.0_B_mKate_49',)          62.1430
#
#       norm_mean-background
# 0                 0.518172
# 1                 1.340941
# 2                 5.793343
# 3                 1.531702
# 4                 1.240145
# ...                    ...
# 2225              1.365458
# 2226              3.345120
# 2227              0.422787
# 2228              0.350588
# 2229              0.420534
#
# [43452 rows x 19 columns]

# %% [markdown]
# # Counting Mean Cell ns

# %%
df_img_ns = df_full.groupby('rat_n')['image_name'].unique().reset_index()
df_img_ns['n_imgs'] = df_img_ns.image_name.apply(len)
df_img_ns
# Out:
#         rat_n                                         image_name  n_imgs
# 0   RAM-12_11  [RAM-12_11_PFC_3.5_A, RAM-12_11_PFC_3.7_B, RAM...       4
# 1   RAM-12_12  [RAM-12_12_PFC_3.4_A, RAM-12_12_PFC_3.4_B, RAM...       4
# 2   RAM-12_13  [RAM-12_13_PFC_3.7_B, RAM-12_13_PFC_3.7_C, RAM...       4
# 3   RAM-12_14  [RAM-12_14_PFC_3.8_C, RAM-12_14_PFC_3.8_D, RAM...       4
# 4   RAM-12_16  [RAM-12_16_PFC_3.7_D, RAM-12_16_PFC_4.0_A, RAM...       4
# 5    RAM-12_3  [RAM-12_3_PFC_3.7_A, RAM-12_3_PFC_3.7_B, RAM-1...       4
# 6    RAM-12_6  [RAM-12_6_PFC_3.5_A, RAM-12_6_PFC_3.5_B, RAM-1...       3
# 7    RAM-12_7  [RAM-12_7_PFC_3.5_C, RAM-12_7_PFC_3.5_D, RAM-1...       4
# 8    RAM-13_1  [RAM-13_1_PFC_3.5_C, RAM-13_1_PFC_3.5_D, RAM-1...       4
# 9    RAM-13_3  [RAM-13_3_PFC_3.3_D, RAM-13_3_PFC_3.5_E, RAM-1...       5
# 10   RAM-13_5  [RAM-13_5_PFC_3.2_A, RAM-13_5_PFC_3.3_C, RAM-1...       4
# 11   RAM-13_7  [RAM-13_7_PFC_3.0_C, RAM-13_7_PFC_3.5_B, RAM-1...       4
# 12   RAM-13_8  [RAM-13_8_PFC_3.7_A, RAM-13_8_PFC_3.7_B, RAM-1...       5
# 13   RAM-13_9  [RAM-13_9_PFC_3.3_D, RAM-13_9_PFC_3.5_C, RAM-1...       3
# 14  RAM-14a_3  [RAM-14a_3_PFC_3.2_C, RAM-14a_3_PFC_3.2_D, RAM...       4
# 15  RAM-14a_5  [RAM-14a_5_PFC_3.2_D, RAM-14a_5_PFC_3.7_C, RAM...       4
# 16  RAM-14a_6  [RAM-14a_6_PFC_3.2_D, RAM-14a_6_PFC_3.7_A, RAM...       4
# 17  RAM-14a_7  [RAM-14a_7_PFC_3.5_A, RAM-14a_7_PFC_3.5_B, RAM...       4
# 18  RAM-14a_8  [RAM-14a_8_PFC_3.3_D, RAM-14a_8_PFC_3.5_C, RAM...       4
# 19  RAM-14b_1  [RAM-14b_1_PFC_3.7_D, RAM-14b_1_PFC_3.9_B, RAM...       4
# 20  RAM-14b_2  [RAM-14b_2_PFC_3.5_D, RAM-14b_2_PFC_3.7_C, RAM...       4
# 21  RAM-14b_3  [RAM-14b_3_PFC_3.3_D, RAM-14b_3_PFC_3.7_C, RAM...       4
# 22  RAM-14b_4  [RAM-14b_4_PFC_3.7_C, RAM-14b_4_PFC_3.9_B, RAM...       4
# 23  RAM-14b_5  [RAM-14b_5_PFC_3.2_D, RAM-14b_5_PFC_3.5_B, RAM...       4
# 24  RAM-14b_6         [RAM-14b_6_PFC_3.2_A, RAM-14b_6_PFC_3.5_B]       2
# 25  RAM-14b_7                              [RAM-14b_7_PFC_3.7_B]       1
# 26  RAM-14b_8  [RAM-14b_8_PFC_3.5_C, RAM-14b_8_PFC_3.7_D, RAM...       4

# %% [markdown]
# ## Single cFos, single mKate

# %%
def mean_cell_ns_single(stain_x):
    # series of groupby's and reductions to get sum of sums per rat
    # first groupby to count cells per image; second groupby to sum counts per rat
    # merge with df_full to get required labels, merge with df_img_ns to get n_imgs per rat
    q = df_full.query(f'dummy_{stain_x} == True and stain == "{stain_x}"')\
        .groupby('image_name')['rat_n'].count()\
        .reset_index().rename(columns={'rat_n':'count'})\
        .merge(df_full[['image_name', 'rat_n']], on='image_name', how='left')\
        .drop_duplicates()\
        .groupby('rat_n')['count'].sum().reset_index().rename(columns={'count':'sum'})\
        .merge(df_full[['rat_n', 'react', 'treatment', 'dox']],\
            on='rat_n', how='left')\
        .drop_duplicates().reset_index()\
        .merge(df_img_ns[['rat_n', 'n_imgs']], on='rat_n', how='left')

    # compute means
    q['mean_cell_n'] = q['sum'] / q['n_imgs']

    # sort by dox, then treatment, then react; reorder cols
    q = q.sort_values(by=['dox', 'treatment', 'react'])\
        [['rat_n', 'dox', 'treatment', 'react', 'sum', 'n_imgs', 'mean_cell_n']]\
        .reset_index().drop('index', axis=1)

    return q

# these should be identical, but i'm performing both queries for completeness
mean_cell_ns_single('cFos').to_csv('RAM-12,13,14_cFos_mean_cell_ns.csv')
mean_cell_ns_single('mKate').to_csv('RAM-12,13,14_mKate_mean_cell_ns.csv')

# %% [markdown]
# ## cFos on mKate, mKate on cFos

# %%
def mean_cell_ns_double(stain_x, stain_y):
    # series of groupby's and reductions to get sum of sums per rat
    # first groupby to count cells per image; second groupby to sum counts per rat
    # merge with df_full to get required labels, merge with df_img_ns to get n_imgs per rat
    q = df_full.query(f'dummy_{stain_x} == True and dummy_{stain_y} == True and stain == "{stain_x}"')\
        .groupby('image_name')['rat_n'].count()\
        .reset_index().rename(columns={'rat_n':'count'})\
        .merge(df_full[['image_name', 'rat_n']], on='image_name', how='left')\
        .drop_duplicates()\
        .groupby('rat_n')['count'].sum().reset_index().rename(columns={'count':'sum'})\
        .merge(df_full[['rat_n', 'react', 'treatment', 'dox']],\
            on='rat_n', how='left')\
        .drop_duplicates().reset_index()\
        .merge(df_img_ns[['rat_n', 'n_imgs']], on='rat_n', how='left')

    # compute means
    q['mean_cell_n'] = q['sum'] / q['n_imgs']

    # sort by dox, then treatment, then react; reorder cols
    q = q.sort_values(by=['dox', 'treatment', 'react'])\
        [['rat_n', 'dox', 'treatment', 'react', 'sum', 'n_imgs', 'mean_cell_n']]\
        .reset_index().drop('index', axis=1)

    return q

# these should be identical, but i'm performing both queries for completeness
mean_cell_ns_double('cFos', 'mKate').to_csv('RAM-12,13,14_cFos_coloc_w_mKate_mean_cell_ns.csv')
mean_cell_ns_double('mKate', 'cFos').to_csv('RAM-12,13,14_mKate_coloc_w_cFos_mean_cell_ns.csv')

# %%
mean_cell_ns_double('cFos', 'mKate')
# Out:
#         rat_n      dox treatment react  sum  n_imgs  mean_cell_n
# 0   RAM-12_12  OFF_DOX       ABC   FR1   22       4     5.500000
# 1   RAM-14b_6  OFF_DOX       ABC   FR1    2       2     1.000000
# 2   RAM-14b_7  OFF_DOX       ABC   FR1    1       1     1.000000
# 3   RAM-14b_8  OFF_DOX       ABC   FR1   57       4    14.250000
# 4    RAM-13_7  OFF_DOX       ABC    NR   62       4    15.500000
# 5   RAM-14b_2  OFF_DOX       ABC    NR   62       4    15.500000
# 6   RAM-14b_4  OFF_DOX       ABC    NR   85       4    21.250000
# 7   RAM-12_11  OFF_DOX       ABC   VR5    9       4     2.250000
# 8   RAM-12_13  OFF_DOX       VEH   FR1   80       4    20.000000
# 9    RAM-13_8  OFF_DOX       VEH   FR1   85       5    17.000000
# 10  RAM-14a_7  OFF_DOX       VEH   FR1   22       4     5.500000
# 11  RAM-14a_8  OFF_DOX       VEH   FR1   35       4     8.750000
# 12  RAM-12_14  OFF_DOX       VEH    NR   20       4     5.000000
# 13   RAM-13_1  OFF_DOX       VEH    NR  232       4    58.000000
# 14  RAM-12_16  OFF_DOX       VEH   VR5  111       4    27.750000
# 15   RAM-13_5  OFF_DOX       VEH   VR5   15       4     3.750000
# 16   RAM-13_9  OFF_DOX       VEH   VR5  123       3    41.000000
# 17  RAM-14a_5  OFF_DOX       VEH   VR5   13       4     3.250000
# 18   RAM-13_3   ON_DOX       ABC    NR  383       5    76.600000
# 19  RAM-14b_1   ON_DOX       ABC    NR    6       4     1.500000
# 20   RAM-12_6   ON_DOX       ABC   VR5    1       3     0.333333
# 21  RAM-14b_3   ON_DOX       ABC   VR5   25       4     6.250000
# 22  RAM-14b_5   ON_DOX       ABC   VR5    4       4     1.000000
# 23  RAM-14a_6   ON_DOX       VEH   FR1   19       4     4.750000
# 24   RAM-12_3   ON_DOX       VEH    NR   11       4     2.750000
# 25   RAM-12_7   ON_DOX       VEH   VR5    6       4     1.500000
# 26  RAM-14a_3   ON_DOX       VEH   VR5  215       4    53.750000

# %% [markdown]
# # Repeat cell ns, but this time with split by cFos intensity (median split)

# %% [markdown]
# ## cFos_hi

# %%
df_cFos = df_full.query('dummy_cFos == True and stain =="cFos"').copy()
cFos_median = df_cFos['norm_mean-background'].median()
df_cFos['cFos_split'] = df_cFos['norm_mean-background'].apply(lambda x: 'cFos_hi' if x > cFos_median else 'cFos_lo')

q = df_cFos.query('cFos_split == "cFos_hi"')\
    .groupby(['cFos_split', 'image_name'])['rat_n'].count()\
    .reset_index().rename(columns={'rat_n':'count'})\
    .merge(df_cFos[['image_name','rat_n']], on='image_name', how='left')\
    .drop_duplicates()\
    .groupby(['rat_n', 'cFos_split'])['count'].sum().reset_index().rename(columns={'count':'sum'})\
    .merge(df_full[['rat_n', 'react', 'treatment', 'dox']],\
        on='rat_n', how='left')\
    .drop_duplicates().reset_index()\
    .merge(df_img_ns[['rat_n', 'n_imgs']], on='rat_n', how='left')

# compute means
q['mean_cell_n'] = q['sum'] / q['n_imgs']

# sort by dox, then treatment, then react; reorder cols
q = q.sort_values(by=['dox', 'treatment', 'react'])\
    [['rat_n', 'dox', 'treatment', 'react', 'cFos_split', 'sum', 'n_imgs', 'mean_cell_n']]\
    .reset_index().drop('index', axis=1)

q.to_csv('RAM-12,13,14_cFos_hi_mean_cell_ns.csv')
q
# Out:
#         rat_n      dox treatment react cFos_split  sum  n_imgs  mean_cell_n
# 0   RAM-12_12  OFF_DOX       ABC   FR1    cFos_hi  253       4    63.250000
# 1   RAM-14b_6  OFF_DOX       ABC   FR1    cFos_hi   74       2    37.000000
# 2   RAM-14b_7  OFF_DOX       ABC   FR1    cFos_hi   62       1    62.000000
# 3   RAM-14b_8  OFF_DOX       ABC   FR1    cFos_hi  351       4    87.750000
# 4    RAM-13_7  OFF_DOX       ABC    NR    cFos_hi  464       4   116.000000
# 5   RAM-14b_2  OFF_DOX       ABC    NR    cFos_hi  495       4   123.750000
# 6   RAM-14b_4  OFF_DOX       ABC    NR    cFos_hi  770       4   192.500000
# 7   RAM-12_11  OFF_DOX       ABC   VR5    cFos_hi   88       4    22.000000
# 8   RAM-12_13  OFF_DOX       VEH   FR1    cFos_hi  290       4    72.500000
# 9    RAM-13_8  OFF_DOX       VEH   FR1    cFos_hi  298       5    59.600000
# 10  RAM-14a_7  OFF_DOX       VEH   FR1    cFos_hi  220       4    55.000000
# 11  RAM-14a_8  OFF_DOX       VEH   FR1    cFos_hi  208       4    52.000000
# 12  RAM-12_14  OFF_DOX       VEH    NR    cFos_hi  351       4    87.750000
# 13   RAM-13_1  OFF_DOX       VEH    NR    cFos_hi  541       4   135.250000
# 14  RAM-12_16  OFF_DOX       VEH   VR5    cFos_hi  287       4    71.750000
# 15   RAM-13_5  OFF_DOX       VEH   VR5    cFos_hi  167       4    41.750000
# 16   RAM-13_9  OFF_DOX       VEH   VR5    cFos_hi  383       3   127.666667
# 17  RAM-14a_5  OFF_DOX       VEH   VR5    cFos_hi   85       4    21.250000
# 18   RAM-13_3   ON_DOX       ABC    NR    cFos_hi  728       5   145.600000
# 19  RAM-14b_1   ON_DOX       ABC    NR    cFos_hi  757       4   189.250000
# 20   RAM-12_6   ON_DOX       ABC   VR5    cFos_hi  106       3    35.333333
# 21  RAM-14b_3   ON_DOX       ABC   VR5    cFos_hi  648       4   162.000000
# 22  RAM-14b_5   ON_DOX       ABC   VR5    cFos_hi  280       4    70.000000
# 23  RAM-14a_6   ON_DOX       VEH   FR1    cFos_hi  187       4    46.750000
# 24   RAM-12_3   ON_DOX       VEH    NR    cFos_hi  160       4    40.000000
# 25   RAM-12_7   ON_DOX       VEH   VR5    cFos_hi  133       4    33.250000
# 26  RAM-14a_3   ON_DOX       VEH   VR5    cFos_hi  378       4    94.500000

# %% [markdown]
# ## cFos_lo

# %%
q = df_cFos.query('cFos_split == "cFos_lo"')\
    .groupby(['cFos_split', 'image_name'])['rat_n'].count()\
    .reset_index().rename(columns={'rat_n':'count'})\
    .merge(df_cFos[['image_name','rat_n']], on='image_name', how='left')\
    .drop_duplicates()\
    .groupby(['rat_n', 'cFos_split'])['count'].sum().reset_index().rename(columns={'count':'sum'})\
    .merge(df_full[['rat_n', 'react', 'treatment', 'dox']],\
        on='rat_n', how='left')\
    .drop_duplicates().reset_index()\
    .merge(df_img_ns[['rat_n', 'n_imgs']], on='rat_n', how='left')

# compute means
q['mean_cell_n'] = q['sum'] / q['n_imgs']

# sort by dox, then treatment, then react; reorder cols
q = q.sort_values(by=['dox', 'treatment', 'react'])\
    [['rat_n', 'dox', 'treatment', 'react', 'cFos_split', 'sum', 'n_imgs', 'mean_cell_n']]\
    .reset_index().drop('index', axis=1)

q.to_csv('RAM-12,13,14_cFos_lo_mean_cell_ns.csv')
q
# Out:
#         rat_n      dox treatment react cFos_split  sum  n_imgs  mean_cell_n
# 0   RAM-12_12  OFF_DOX       ABC   FR1    cFos_lo  187       4    46.750000
# 1   RAM-14b_6  OFF_DOX       ABC   FR1    cFos_lo  122       2    61.000000
# 2   RAM-14b_7  OFF_DOX       ABC   FR1    cFos_lo   64       1    64.000000
# 3   RAM-14b_8  OFF_DOX       ABC   FR1    cFos_lo  409       4   102.250000
# 4    RAM-13_7  OFF_DOX       ABC    NR    cFos_lo  816       4   204.000000
# 5   RAM-14b_2  OFF_DOX       ABC    NR    cFos_lo  456       4   114.000000
# 6   RAM-14b_4  OFF_DOX       ABC    NR    cFos_lo  295       4    73.750000
# 7   RAM-12_11  OFF_DOX       ABC   VR5    cFos_lo   27       4     6.750000
# 8   RAM-12_13  OFF_DOX       VEH   FR1    cFos_lo  425       4   106.250000
# 9    RAM-13_8  OFF_DOX       VEH   FR1    cFos_lo  518       5   103.600000
# 10  RAM-14a_7  OFF_DOX       VEH   FR1    cFos_lo  350       4    87.500000
# 11  RAM-14a_8  OFF_DOX       VEH   FR1    cFos_lo  374       4    93.500000
# 12  RAM-12_14  OFF_DOX       VEH    NR    cFos_lo  139       4    34.750000
# 13   RAM-13_1  OFF_DOX       VEH    NR    cFos_lo  558       4   139.500000
# 14  RAM-12_16  OFF_DOX       VEH   VR5    cFos_lo  273       4    68.250000
# 15   RAM-13_5  OFF_DOX       VEH   VR5    cFos_lo  193       4    48.250000
# 16   RAM-13_9  OFF_DOX       VEH   VR5    cFos_lo  545       3   181.666667
# 17  RAM-14a_5  OFF_DOX       VEH   VR5    cFos_lo  232       4    58.000000
# 18   RAM-13_3   ON_DOX       ABC    NR    cFos_lo  754       5   150.800000
# 19  RAM-14b_1   ON_DOX       ABC    NR    cFos_lo  591       4   147.750000
# 20   RAM-12_6   ON_DOX       ABC   VR5    cFos_lo  119       3    39.666667
# 21  RAM-14b_3   ON_DOX       ABC   VR5    cFos_lo  521       4   130.250000
# 22  RAM-14b_5   ON_DOX       ABC   VR5    cFos_lo  169       4    42.250000
# 23  RAM-14a_6   ON_DOX       VEH   FR1    cFos_lo  115       4    28.750000
# 24   RAM-12_3   ON_DOX       VEH    NR    cFos_lo  253       4    63.250000
# 25   RAM-12_7   ON_DOX       VEH   VR5    cFos_lo  122       4    30.500000
# 26  RAM-14a_3   ON_DOX       VEH   VR5    cFos_lo  138       4    34.500000

# %%
q = df_cFos.query('cFos_split == "cFos_hi" and dummy_mKate == True')\
    .groupby(['cFos_split', 'image_name'])['rat_n'].count()\
    .reset_index().rename(columns={'rat_n':'count'})\
    .merge(df_cFos[['image_name','rat_n']], on='image_name', how='left')\
    .drop_duplicates()\
    .groupby(['rat_n', 'cFos_split'])['count'].sum().reset_index().rename(columns={'count':'sum'})\
    .merge(df_full[['rat_n', 'react', 'treatment', 'dox']],\
        on='rat_n', how='left')\
    .drop_duplicates().reset_index()\
    .merge(df_img_ns[['rat_n', 'n_imgs']], on='rat_n', how='left')

# compute means
q['mean_cell_n'] = q['sum'] / q['n_imgs']

# sort by dox, then treatment, then react; reorder cols
q = q.sort_values(by=['dox', 'treatment', 'react'])\
    [['rat_n', 'dox', 'treatment', 'react', 'cFos_split', 'sum', 'n_imgs', 'mean_cell_n']]\
    .reset_index().drop('index', axis=1)

# fill in rats who did not have this stain type combination with 0
missing = set(df_img_ns.rat_n) - set(q.rat_n)
df_missing = df_key[df_key.rat_n.isin(missing)].copy()
df_missing['cFos_split'] = 'cFos_hi'
df_missing['sum'] = 0
df_missing = df_missing.merge(df_img_ns[['rat_n', 'n_imgs']], on='rat_n', how='left')
df_missing['mean_cell_n'] = df_missing['sum'] / df_missing['n_imgs']
df_missing
q = pd.concat([q, df_missing]).sort_values(by=['dox', 'treatment', 'react']).reset_index().drop('index', axis=1)

q.to_csv('RAM-12,13,14_cFos_hi_coloc_w_mKate_mean_cell_ns.csv')
q
# Out:
#         rat_n      dox treatment react cFos_split  sum  n_imgs  mean_cell_n
# 0   RAM-12_12  OFF_DOX       ABC   FR1    cFos_hi   16       4     4.000000
# 1   RAM-14b_6  OFF_DOX       ABC   FR1    cFos_hi    2       2     1.000000
# 2   RAM-14b_8  OFF_DOX       ABC   FR1    cFos_hi   31       4     7.750000
# 3   RAM-14b_7  OFF_DOX       ABC   FR1    cFos_hi    0       1     0.000000
# 4    RAM-13_7  OFF_DOX       ABC    NR    cFos_hi   39       4     9.750000
# 5   RAM-14b_2  OFF_DOX       ABC    NR    cFos_hi   43       4    10.750000
# 6   RAM-14b_4  OFF_DOX       ABC    NR    cFos_hi   72       4    18.000000
# 7   RAM-12_11  OFF_DOX       ABC   VR5    cFos_hi    6       4     1.500000
# 8   RAM-12_13  OFF_DOX       VEH   FR1    cFos_hi   38       4     9.500000
# 9    RAM-13_8  OFF_DOX       VEH   FR1    cFos_hi   36       5     7.200000
# 10  RAM-14a_7  OFF_DOX       VEH   FR1    cFos_hi   13       4     3.250000
# 11  RAM-14a_8  OFF_DOX       VEH   FR1    cFos_hi   21       4     5.250000
# 12  RAM-12_14  OFF_DOX       VEH    NR    cFos_hi   18       4     4.500000
# 13   RAM-13_1  OFF_DOX       VEH    NR    cFos_hi  135       4    33.750000
# 14  RAM-12_16  OFF_DOX       VEH   VR5    cFos_hi   82       4    20.500000
# 15   RAM-13_5  OFF_DOX       VEH   VR5    cFos_hi   12       4     3.000000
# 16   RAM-13_9  OFF_DOX       VEH   VR5    cFos_hi   75       3    25.000000
# 17  RAM-14a_5  OFF_DOX       VEH   VR5    cFos_hi    6       4     1.500000
# 18   RAM-13_3   ON_DOX       ABC    NR    cFos_hi  211       5    42.200000
# 19  RAM-14b_1   ON_DOX       ABC    NR    cFos_hi    4       4     1.000000
# 20   RAM-12_6   ON_DOX       ABC   VR5    cFos_hi    1       3     0.333333
# 21  RAM-14b_3   ON_DOX       ABC   VR5    cFos_hi   13       4     3.250000
# 22  RAM-14b_5   ON_DOX       ABC   VR5    cFos_hi    4       4     1.000000
# 23  RAM-14a_6   ON_DOX       VEH   FR1    cFos_hi   15       4     3.750000
# 24   RAM-12_3   ON_DOX       VEH    NR    cFos_hi    6       4     1.500000
# 25   RAM-12_7   ON_DOX       VEH   VR5    cFos_hi    3       4     0.750000
# 26  RAM-14a_3   ON_DOX       VEH   VR5    cFos_hi  184       4    46.000000

# %%
q = df_cFos.query('cFos_split == "cFos_lo" and dummy_mKate == True')\
    .groupby(['cFos_split', 'image_name'])['rat_n'].count()\
    .reset_index().rename(columns={'rat_n':'count'})\
    .merge(df_cFos[['image_name','rat_n']], on='image_name', how='left')\
    .drop_duplicates()\
    .groupby(['rat_n', 'cFos_split'])['count'].sum().reset_index().rename(columns={'count':'sum'})\
    .merge(df_full[['rat_n', 'react', 'treatment', 'dox']],\
        on='rat_n', how='left')\
    .drop_duplicates().reset_index()\
    .merge(df_img_ns[['rat_n', 'n_imgs']], on='rat_n', how='left')

# compute means
q['mean_cell_n'] = q['sum'] / q['n_imgs']

# sort by dox, then treatment, then react; reorder cols
q = q.sort_values(by=['dox', 'treatment', 'react'])\
    [['rat_n', 'dox', 'treatment', 'react', 'cFos_split', 'sum', 'n_imgs', 'mean_cell_n']]\
    .reset_index().drop('index', axis=1)

# fill in rats who did not have this stain type combination with 0
missing = set(df_img_ns.rat_n) - set(q.rat_n)
df_missing = df_key[df_key.rat_n.isin(missing)].copy()
df_missing['cFos_split'] = 'cFos_hi'
df_missing['sum'] = 0
df_missing = df_missing.merge(df_img_ns[['rat_n', 'n_imgs']], on='rat_n', how='left')
df_missing['mean_cell_n'] = df_missing['sum'] / df_missing['n_imgs']
df_missing
q = pd.concat([q, df_missing]).sort_values(by=['dox', 'treatment', 'react']).reset_index().drop('index', axis=1)

q.to_csv('RAM-12,13,14_cFos_lo_coloc_w_mKate_mean_cell_ns.csv')
q
# Out:
#         rat_n      dox treatment react cFos_split  sum  n_imgs  mean_cell_n
# 0   RAM-12_12  OFF_DOX       ABC   FR1    cFos_lo    6       4         1.50
# 1   RAM-14b_7  OFF_DOX       ABC   FR1    cFos_lo    1       1         1.00
# 2   RAM-14b_8  OFF_DOX       ABC   FR1    cFos_lo   26       4         6.50
# 3   RAM-14b_6  OFF_DOX       ABC   FR1    cFos_hi    0       2         0.00
# 4    RAM-13_7  OFF_DOX       ABC    NR    cFos_lo   23       4         5.75
# 5   RAM-14b_2  OFF_DOX       ABC    NR    cFos_lo   19       4         4.75
# 6   RAM-14b_4  OFF_DOX       ABC    NR    cFos_lo   13       4         3.25
# 7   RAM-12_11  OFF_DOX       ABC   VR5    cFos_lo    3       4         0.75
# 8   RAM-12_13  OFF_DOX       VEH   FR1    cFos_lo   42       4        10.50
# 9    RAM-13_8  OFF_DOX       VEH   FR1    cFos_lo   49       5         9.80
# 10  RAM-14a_7  OFF_DOX       VEH   FR1    cFos_lo    9       4         2.25
# 11  RAM-14a_8  OFF_DOX       VEH   FR1    cFos_lo   14       4         3.50
# 12  RAM-12_14  OFF_DOX       VEH    NR    cFos_lo    2       4         0.50
# 13   RAM-13_1  OFF_DOX       VEH    NR    cFos_lo   97       4        24.25
# 14  RAM-12_16  OFF_DOX       VEH   VR5    cFos_lo   29       4         7.25
# 15   RAM-13_5  OFF_DOX       VEH   VR5    cFos_lo    3       4         0.75
# 16   RAM-13_9  OFF_DOX       VEH   VR5    cFos_lo   48       3        16.00
# 17  RAM-14a_5  OFF_DOX       VEH   VR5    cFos_lo    7       4         1.75
# 18   RAM-13_3   ON_DOX       ABC    NR    cFos_lo  172       5        34.40
# 19  RAM-14b_1   ON_DOX       ABC    NR    cFos_lo    2       4         0.50
# 20  RAM-14b_3   ON_DOX       ABC   VR5    cFos_lo   12       4         3.00
# 21   RAM-12_6   ON_DOX       ABC   VR5    cFos_hi    0       3         0.00
# 22  RAM-14b_5   ON_DOX       ABC   VR5    cFos_hi    0       4         0.00
# 23  RAM-14a_6   ON_DOX       VEH   FR1    cFos_lo    4       4         1.00
# 24   RAM-12_3   ON_DOX       VEH    NR    cFos_lo    5       4         1.25
# 25   RAM-12_7   ON_DOX       VEH   VR5    cFos_lo    3       4         0.75
# 26  RAM-14a_3   ON_DOX       VEH   VR5    cFos_lo   31       4         7.75
